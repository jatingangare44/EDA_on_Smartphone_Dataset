# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\jatin\Downloads\smartphones.csv")

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df.tail()
# Out:
#                                 model    price  rating  \
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                            processor  \
# 1015   Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016  Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017   Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018    Snapdragon 695, Octa Core, 2.2 GHz Processor
# ...

# %%
df.sample(10)
# Out:
#                                                   model    price  rating  \
# 686                           iQOO Neo 7 Racing Edition  ₹32,990    84.0
# 235                                         Vivo T1 44W  ₹14,499    77.0
# 142                                      Poco M4 Pro 5G  ₹12,999    76.0
# 798                             Samsung Galaxy S20 Plus  ₹83,000    88.0
# 320                          iQOO 11 (16GB RAM + 256GB)  ₹64,999    89.0
# 503                  Motorola Moto G31 (6GB RAM+ 128GB)  ₹11,999    78.0
# 86                                Samsung Galaxy A23 5G  ₹22,999    79.0
# 1009                                      Xiaomi Civi 3  ₹32,990    86.0
# 837                                           Vivo Y21T  ₹15,499    74.0
# 275   Xiaomi Redmi Note 11 Pro Plus 5G (8GB RAM + 12...  ₹22,700    86.0
#
#                                                     sim  \
# 686   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %% [markdown]
# Data Cleaning

# %%
df.isnull().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['rating'].fillna(df['rating'].mean(), inplace=True)
df
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df.isnull().sum()
# Out:
# model         0
# price         0
# rating        0
# sim           0
# processor     0
# ram           0
# battery       0
# display       0
# camera        1
# card          7
# os           17
# dtype: int64

# %%
df['camera'].isnull().sum()
# Out:
# 1

# %%
# Find the row indices where the specified column has null values
null_indices = df[df['camera'].isnull()].index

# Display the row indices with null values in the specified column
print(null_indices)
# Out:
# Index([699], dtype='int64')

# %%
#iloc is used to select specific row with its indices
print(df.iloc[699])
# Out:
# model                   Samsung Guru GT-E1215
# price                                  ₹1,850
# rating                              78.258248
# sim                                Single Sim
# processor                     800 mAh Battery
# ram          1.5 inches, 120 x 120 px Display
# battery                        No Rear Camera
# display                           No FM Radio
# camera                                    NaN
# card                                      NaN
# os                                        NaN
# Name: 699, dtype: object

# %%
df['os'].dropna()
# Out:
# 0       Android v13
# 1       Android v12
# 2       Android v13
# 3       Android v12
# 4       Android v13
#            ...
# 1015    No FM Radio
# 1016    Android v11
# 1017    Android v12
# 1018    Android v12
# 1019    Android v12
# Name: os, Length: 1003, dtype: object

# %%
df.isnull().sum()
# Out:
# model         0
# price         0
# rating        0
# sim           0
# processor     0
# ram           0
# battery       0
# display       0
# camera        1
# card          7
# os           17
# dtype: int64

# %%
dropedcol=df.drop(['card','os','display'],axis=1)

# %%
df1=dropedcol.dropna()

# %%
df1.isnull().sum()
# Out:
# model        0
# price        0
# rating       0
# sim          0
# processor    0
# ram          0
# battery      0
# camera       0
# dtype: int64

# %% [markdown]
# price - has unneccesary '₹' validity
# price - has ',' between numbers validity

# %%
df1_copy = df1.copy()
df1_copy['price'] = df1_copy['price'].str.replace('₹', '').str.replace(',', '')
df1_copy
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# Create new columns with initial values as False
df1_copy[['has_5g', 'has_NFC', 'has_IR_Blaster']] = False

# Update the new columns based on the 'sim' column
df1_copy['has_5g'] = df1_copy['sim'].str.contains('5G')
df1_copy['has_NFC'] = df1_copy['sim'].str.contains('NFC')
df1_copy['has_IR_Blaster'] = df1_copy['sim'].str.contains('IR Blaster')

# Drop the original 'sim' column
df1_copy.drop('sim', axis=1, inplace=True)
df1_copy
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# ...

# %%
df1_copy.columns
# Out:
# Index(['model', 'price', 'rating', 'processor', 'ram', 'battery', 'camera',
#        'has_5g', 'has_NFC', 'has_IR_Blaster'],
#       dtype='object')

# %%
# Display the original DataFrame
print("Original DataFrame:")
print(df1_copy)

# Split the 'model' column into 'brand' and 'model'
df1_copy[['brand', 'model']] = df1_copy['model'].str.split(n=1, expand=True)
df1_copy
# Out:
# Original DataFrame:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# ...

# %%
df1_copy.columns
# Out:
# Index(['model', 'price', 'rating', 'processor', 'ram', 'battery', 'camera',
#        'has_5g', 'has_NFC', 'has_IR_Blaster', 'brand'],
#       dtype='object')

# %%
df1_copy.head()
# Out:
#                model  price  rating  \
# 0              11 5G  54999    89.0
# 1  Nord CE 2 Lite 5G  19989    81.0
# 2      Galaxy A14 5G  16499    75.0
# 3        Moto G62 5G  14999    81.0
# 4        10 Pro Plus  24999    82.0
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
# ...

# %%
# Split the 'processor' column into 'processor_name', 'core', and 'processor_speed'
df1_copy[['processor_name', 'core', 'processor_speed']] = df1_copy['processor'].str.split(', ', expand=True)

# Drop the original 'processor' column
df1_copy.drop('processor', axis=1, inplace=True)
df1_copy
# Out:
#                            model  price  rating                        ram  \
# 0                          11 5G  54999    89.0  12 GB RAM, 256 GB inbuilt
# 1              Nord CE 2 Lite 5G  19989    81.0   6 GB RAM, 128 GB inbuilt
# 2                  Galaxy A14 5G  16499    75.0    4 GB RAM, 64 GB inbuilt
# 3                    Moto G62 5G  14999    81.0   6 GB RAM, 128 GB inbuilt
# 4                    10 Pro Plus  24999    82.0   6 GB RAM, 128 GB inbuilt
# ...                          ...    ...     ...                        ...
# 1015           Moto Edge S30 Pro  34990    83.0   8 GB RAM, 128 GB inbuilt
# 1016                       X8 5G  14990    75.0   6 GB RAM, 128 GB inbuilt
# 1017  X4 GT 5G (8GB RAM + 256GB)  28990    85.0   8 GB RAM, 256 GB inbuilt
# 1018                 Moto G91 5G  19990    80.0   6 GB RAM, 128 GB inbuilt
# 1019              Galaxy M52s 5G  24990    74.0   8 GB RAM, 128 GB inbuilt
#
#                                         battery  \
# ...

# %%
df1_copy.head()
# Out:
#                model  price  rating                        ram  \
# 0              11 5G  54999    89.0  12 GB RAM, 256 GB inbuilt
# 1  Nord CE 2 Lite 5G  19989    81.0   6 GB RAM, 128 GB inbuilt
# 2      Galaxy A14 5G  16499    75.0    4 GB RAM, 64 GB inbuilt
# 3        Moto G62 5G  14999    81.0   6 GB RAM, 128 GB inbuilt
# 4        10 Pro Plus  24999    82.0   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                               camera  has_5g  has_NFC  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...    True     True
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...    True    False
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...    True    False
# ...

# %%
# Extract only numeric part from the 'battery' column as 'battery_capacity'
df1_copy['battery_capacity'] = df1_copy['battery'].str.extract(r'(\d+)', expand=False)

# Convert the 'battery_capacity' column to numeric, setting NaN values to 0
df1_copy['battery_capacity'] = pd.to_numeric(df1_copy['battery_capacity'], errors='coerce').fillna(0).astype(int)

# Create a boolean column 'supports_fast_charging'
df1_copy['supports_fast_charging'] = df1_copy['battery'].str.contains('Fast Charging', case=False)

# Drop the original 'battery' column
df1_copy.drop('battery', axis=1, inplace=True)

# %%
df1_copy.head()
# Out:
#                model  price  rating                        ram  \
# 0              11 5G  54999    89.0  12 GB RAM, 256 GB inbuilt
# 1  Nord CE 2 Lite 5G  19989    81.0   6 GB RAM, 128 GB inbuilt
# 2      Galaxy A14 5G  16499    75.0    4 GB RAM, 64 GB inbuilt
# 3        Moto G62 5G  14999    81.0   6 GB RAM, 128 GB inbuilt
# 4        10 Pro Plus  24999    82.0   6 GB RAM, 128 GB inbuilt
#
#                                               camera  has_5g  has_NFC  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...    True     True
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...    True    False
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...    True    False
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...    True    False
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...    True    False
#
#    has_IR_Blaster     brand     processor_name       core    processor_speed  \
# 0           False   OnePlus  Snapdragon 8 Gen2  Octa Core  3.2 GHz Processor
# ...

# %%
df1_copy.columns
# Out:
# Index(['model', 'price', 'rating', 'ram', 'camera', 'has_5g', 'has_NFC',
#        'has_IR_Blaster', 'brand', 'processor_name', 'core', 'processor_speed',
#        'battery_capacity', 'supports_fast_charging'],
#       dtype='object')

# %%
df1_copy[['ram', 'rom']] = df1_copy['ram'].str.extract(r'(\d+)\s*GB RAM, (\d+)\s*GB inbuilt', expand=True)

# Convert 'ram' and 'rom' columns to numeric, handling NaN values
df1_copy['ram'] = pd.to_numeric(df1_copy['ram'], errors='coerce')
df1_copy['rom'] = pd.to_numeric(df1_copy['rom'], errors='coerce')

# %%
df1_copy.head()
# Out:
#                model  price  rating   ram  \
# 0              11 5G  54999    89.0  12.0
# 1  Nord CE 2 Lite 5G  19989    81.0   6.0
# 2      Galaxy A14 5G  16499    75.0   4.0
# 3        Moto G62 5G  14999    81.0   6.0
# 4        10 Pro Plus  24999    82.0   6.0
#
#                                               camera  has_5g  has_NFC  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...    True     True
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...    True    False
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...    True    False
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...    True    False
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...    True    False
#
#    has_IR_Blaster     brand     processor_name       core    processor_speed  \
# 0           False   OnePlus  Snapdragon 8 Gen2  Octa Core  3.2 GHz Processor
# 1           False   OnePlus     Snapdragon 695  Octa Core  2.2 GHz Processor
# ...

# %%
# Drop the original 'camera' column
df1_copy.drop('camera', axis=1, inplace=True)

# %%
df1_copy.head()
# Out:
#                model  price  rating   ram  has_5g  has_NFC  has_IR_Blaster  \
# 0              11 5G  54999    89.0  12.0    True     True           False
# 1  Nord CE 2 Lite 5G  19989    81.0   6.0    True    False           False
# 2      Galaxy A14 5G  16499    75.0   4.0    True    False           False
# 3        Moto G62 5G  14999    81.0   6.0    True    False           False
# 4        10 Pro Plus  24999    82.0   6.0    True    False           False
#
#       brand     processor_name       core    processor_speed  \
# 0   OnePlus  Snapdragon 8 Gen2  Octa Core  3.2 GHz Processor
# 1   OnePlus     Snapdragon 695  Octa Core  2.2 GHz Processor
# 2   Samsung        Exynos 1330  Octa Core  2.4 GHz Processor
# 3  Motorola    Snapdragon  695  Octa Core  2.2 GHz Processor
# 4    Realme     Dimensity 1080  Octa Core  2.6 GHz Processor
#
#    battery_capacity  supports_fast_charging    rom
# 0              5000                    True  256.0
# ...

# %%
# Rename the 'processor_speed' column
df1_copy.rename(columns={'processor_speed': 'processor_speed (GHz)'}, inplace=True)

# Remove non-digit characters from the 'processor_speed (GHz)' column values
df1_copy['processor_speed (GHz)'] = df1_copy['processor_speed (GHz)'].replace('[^\d.]', '', regex=True)

# %%
df1_copy.head()
# Out:
#                model  price  rating   ram  has_5g  has_NFC  has_IR_Blaster  \
# 0              11 5G  54999    89.0  12.0    True     True           False
# 1  Nord CE 2 Lite 5G  19989    81.0   6.0    True    False           False
# 2      Galaxy A14 5G  16499    75.0   4.0    True    False           False
# 3        Moto G62 5G  14999    81.0   6.0    True    False           False
# 4        10 Pro Plus  24999    82.0   6.0    True    False           False
#
#       brand     processor_name       core processor_speed (GHz)  \
# 0   OnePlus  Snapdragon 8 Gen2  Octa Core                   3.2
# 1   OnePlus     Snapdragon 695  Octa Core                   2.2
# 2   Samsung        Exynos 1330  Octa Core                   2.4
# 3  Motorola    Snapdragon  695  Octa Core                   2.2
# 4    Realme     Dimensity 1080  Octa Core                   2.6
#
#    battery_capacity  supports_fast_charging    rom
# 0              5000                    True  256.0
# ...

# %%
df1_copy.isnull().sum()
# Out:
# model                      0
# price                      0
# rating                     0
# ram                       46
# has_5g                     0
# has_NFC                    0
# has_IR_Blaster             0
# brand                      0
# processor_name             0
# core                      37
# processor_speed (GHz)     88
# battery_capacity           0
# supports_fast_charging     0
# rom                       46
# dtype: int64

# %%
df1_copy['core'].unique()
# Out:
# array(['Octa Core', 'Hexa Core', 'Hexa Core Processor', 'Quad Core',
#        'Octa Core Processor', None, '1.4\u2009GHz Processor',
#        '1.6\u2009GHz Processor', '2\u2009GHz Processor', 'Dual Core',
#        '1.3\u2009GHz Processor', '1\u2009GHz Processor',
#        '4\u2009GB inbuilt', '4\u2009MB inbuilt', '32\u2009MB inbuilt',
#        '2.2\u2009GHz Processor', '26\u2009MHz Processor',
#        '8\u2009GB inbuilt', '512\u2009MB inbuilt', '128\u2009MB inbuilt',
#        '16\u2009MB inbuilt', '1.8\u2009GHz Processor'], dtype=object)

# %%
df1_copy.drop('core', axis=1, inplace=True)

# %%
# Impute missing values with median for 'ram' and 'rom'
df1_copy['ram'].fillna(df1_copy['ram'].median(), inplace=True)
df1_copy['rom'].fillna(df1_copy['rom'].median(), inplace=True)

# Impute missing values in 'processor_speed (GHz)' using the last valid observation (pad)
df1_copy['processor_speed (GHz)'].fillna(method='pad', inplace=True)

# %%
# Convert 'True' and 'False' to 1 and 0 for specified columns
columns_to_convert = ['has_5g', 'has_NFC', 'has_IR_Blaster','supports_fast_charging']
df1_copy[columns_to_convert] = df1_copy[columns_to_convert].astype(int)

# %%
df1_copy.isnull().sum()
# Out:
# model                     0
# price                     0
# rating                    0
# ram                       0
# has_5g                    0
# has_NFC                   0
# has_IR_Blaster            0
# brand                     0
# processor_name            0
# processor_speed (GHz)     0
# battery_capacity          0
# supports_fast_charging    0
# rom                       0
# dtype: int64

# %%
df1_copy.head()
# Out:
#                model  price  rating   ram  has_5g  has_NFC  has_IR_Blaster  \
# 0              11 5G  54999    89.0  12.0       1        1               0
# 1  Nord CE 2 Lite 5G  19989    81.0   6.0       1        0               0
# 2      Galaxy A14 5G  16499    75.0   4.0       1        0               0
# 3        Moto G62 5G  14999    81.0   6.0       1        0               0
# 4        10 Pro Plus  24999    82.0   6.0       1        0               0
#
#       brand     processor_name processor_speed (GHz)  battery_capacity  \
# 0   OnePlus  Snapdragon 8 Gen2                   3.2              5000
# 1   OnePlus     Snapdragon 695                   2.2              5000
# 2   Samsung        Exynos 1330                   2.4              5000
# 3  Motorola    Snapdragon  695                   2.2              5000
# 4    Realme     Dimensity 1080                   2.6              5000
#
#    supports_fast_charging    rom
# 0                       1  256.0
# ...

# %%
df1_copy.tail()
# Out:
#                            model  price  rating  ram  has_5g  has_NFC  \
# 1015           Moto Edge S30 Pro  34990    83.0  8.0       1        0
# 1016                       X8 5G  14990    75.0  6.0       1        0
# 1017  X4 GT 5G (8GB RAM + 256GB)  28990    85.0  8.0       1        1
# 1018                 Moto G91 5G  19990    80.0  6.0       1        1
# 1019              Galaxy M52s 5G  24990    74.0  8.0       1        0
#
#       has_IR_Blaster     brand       processor_name processor_speed (GHz)  \
# 1015               0  Motorola    Snapdragon 8 Gen1                     3
# 1016               0     Honor     Snapdragon  480+                   2.2
# 1017               1      POCO       Dimensity 8100                  2.85
# 1018               0  Motorola       Snapdragon 695                   2.2
# 1019               0   Samsung  Octa Core Processor                   2.2
#
#       battery_capacity  supports_fast_charging    rom
# ...

# %%
#df1_copy.to_csv("C:\\Users\\jatin\\Documents\\Data Science\\Final Ca2\\Smartphone_cleaned.csv")
